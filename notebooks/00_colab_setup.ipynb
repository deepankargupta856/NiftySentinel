# %% [markdown]
# # NIFTY-Sentinel: Colab setup
# Run this notebook once at the beginning of a new Colab runtime. Outputs are stored in Google Drive because Colab runtimes are temporary.

# %%
from pathlib import Path
PROJECT_ROOT = r'C:\Users\deepa\Documents\ChatGPT\ML 2 porject'
print('Local execution: Google Drive mount skipped.')
# Out:
# Local execution: Google Drive mount skipped.

# %%
import os
os.chdir(r'C:\Users\deepa\Documents\ChatGPT\ML 2 porject')
print('Local execution: skipped Colab shell command: !pip -q install -r requirements-colab.txt')
print('Local execution: skipped Colab shell command: !mkdir -p data/raw data/processed models figures notebooks src website')
# !python -c "from src.config import ensure_project_dirs; ensure_project_dirs(); print('Project directories ready.')"
# Out:
# Local execution: skipped Colab shell command: !pip -q install -r requirements-colab.txt
# Local execution: skipped Colab shell command: !mkdir -p data/raw data/processed models figures notebooks src website
# 'python' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import platform
import numpy as np
import pandas as pd

SEED = 42
np.random.seed(SEED)
print('Python:', platform.python_version())
print('pandas:', pd.__version__)
print('Seed:', SEED)
# Out:
# Python: 3.12.14
# pandas: 3.0.1
# Seed: 42

# %% [markdown]
# ## Before the next notebook
# Download official NSE/RBI files where possible and add each file to `data/source_register.csv`. The exploratory Yahoo Finance pull in the next notebook is a convenience source and must be replaced or validated before final submission.
