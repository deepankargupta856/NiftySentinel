# %% [markdown]
# # NIFTY-Sentinel: dashboard
# Run after `04_supervised_models.ipynb`. This starts the simple Streamlit decision-support website inside Colab.

# %%
import os
os.chdir(r'C:\Users\deepa\Documents\ChatGPT\ML 2 porject')
print('Local execution: skipped Colab shell command: !pip -q install streamlit')
from pathlib import Path
print('Dashboard data is ready.' if Path('data/processed/dashboard_data.csv').exists() else 'Dashboard data is missing.')
# Out:
# Local execution: skipped Colab shell command: !pip -q install streamlit
# Dashboard data is ready.

# %%
print('Local execution: dashboard is served separately on http://127.0.0.1:8080/')
# Out:
# Local execution: dashboard is served separately on http://127.0.0.1:8080/

# %% [markdown]
# ## Deployment
# For a persistent version, commit this project to GitHub and deploy `app.py` through Streamlit Community Cloud or Hugging Face Spaces. Keep API keys out of the repository and add them through the hosting platform's secrets settings.
